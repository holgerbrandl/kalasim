# %% [raw]
# {
#  "cells": [
#   {
#    "cell_type": "code",
#    "metadata": {
#     "collapsed": true,
#     "executionRelatedData": {
#      "compiledClasses": [
#       "Line_20_jupyter",
#       "Line_32_jupyter",
#       "Line_48_jupyter",
#       "Line_6_jupyter",
#       "Line_11_jupyter",
#       "Line_37_jupyter",
#       "Line_26_jupyter",
#       "Line_40_jupyter",
#       "Line_43_jupyter",
#       "Line_52_jupyter"
#      ]
#     },
#     "ExecuteTime": {
#      "end_time": "2026-02-21T17:27:55.072998800Z",
#      "start_time": "2026-02-21T17:27:55.024692200Z"
#     }
#    },
#    "source": [
#     "import kotlinx.datetime.Clock\n",
#     "import org.kalasim.analysis.ResourceActivityEvent\n",
#     "import org.kalasim.collect\n",
#     "import org.kalasim.examples.er.EmergencyRoom\n",
#     "import org.kalasim.Exponential\n",
#     "import org.kalasim.plot.kravis.display\n",
#     "\n",
#     "val er = EmergencyRoom(\n",
#     "    numPhysicians = 5,\n",
#     "    numRooms = 10,\n",
#     "    iatBuilder = Exponential(0.2),\n",
#     "    enableInternalMetrics = true,\n",
#     "    start= Clock.System.now()\n",
#     ")\n"
#    ],
#    "id": "98c04b0092dd7dc6",
#    "outputs": [],
#    "execution_count": 47
#   },
#   {
#    "metadata": {
#     "executionRelatedData": {
#      "compiledClasses": [
#       "Line_7_jupyter",
#       "Line_21_jupyter",
#       "Line_44_jupyter",
#       "Line_10_jupyter",
#       "Line_33_jupyter",
#       "Line_27_jupyter",
#       "Line_41_jupyter",
#       "Line_38_jupyter",
#       "Line_49_jupyter",
#       "Line_12_jupyter",
#       "Line_53_jupyter"
#      ]
#     },
#     "ExecuteTime": {
#      "end_time": "2026-02-21T17:27:56.163971600Z",
#      "start_time": "2026-02-21T17:27:56.010209100Z"
#     }
#    },
#    "cell_type": "code",
#    "source": [
#     "\n",
#     "val rae= er.collect<ResourceActivityEvent> (  )\n",
#     "er.run(90.days)"
#    ],
#    "id": "2f5db924afb3f015",
#    "outputs": [],
#    "execution_count": 48
#   },
#   {
#    "metadata": {
#     "executionRelatedData": {
#      "compiledClasses": [
#       "Line_13_jupyter",
#       "Line_50_jupyter",
#       "Line_28_jupyter",
#       "Line_8_jupyter",
#       "Line_22_jupyter",
#       "Line_45_jupyter",
#       "Line_14_jupyter",
#       "Line_9_jupyter",
#       "Line_46_jupyter",
#       "Line_54_jupyter"
#      ]
#     },
#     "ExecuteTime": {
#      "end_time": "2026-02-21T17:27:56.861369700Z",
#      "start_time": "2026-02-21T17:27:56.759882600Z"
#     }
#    },
#    "cell_type": "code",
#    "source": "er.waitingLine.sizeTimeline.clip(end=er.startDate+4.days).statistics()",
#    "id": "66c5a829fc1dba1f",
#    "outputs": [
#     {
#      "data": {
#       "text/plain": [
#        "{\n",
#        "  \"duration\": \"4d\",\n",
#        "  \"min\": 0,\n",
#        "  \"max\": 2,\n",
#        "  \"mean\": 0.004,\n",
#        "  \"standard_deviation\": 0.067\n",
#        "}"
#       ]
#      },
#      "execution_count": 49,
#      "metadata": {},
#      "output_type": "execute_result"
#     }
#    ],
#    "execution_count": 49
#   },
#   {
#    "metadata": {
#     "executionRelatedData": {
#      "compiledClasses": [
#       "Line_42_jupyter",
#       "Line_47_jupyter",
#       "Line_39_jupyter",
#       "Line_36_jupyter",
#       "Line_51_jupyter",
#       "Line_55_jupyter"
#      ]
#     },
#     "ExecuteTime": {
#      "end_time": "2026-02-21T17:27:59.600168700Z",
#      "start_time": "2026-02-21T17:27:58.015561100Z"
#     }
#    },
#    "cell_type": "code",
#    "source": "er.waitingLine.sizeTimeline.display(\"waiting line (2d)\")\n",
#    "id": "d1901904a643ca64",
#    "outputs": [
#     {
#      "data": {
#       "image/jpeg": "..."
#      },
#      "execution_count": 50,
#      "metadata": {},
#      "output_type": "execute_result"
#     }
#    ],
#    "execution_count": 50
#   },
#   {
#    "metadata": {
#     "executionRelatedData": {
#      "compiledClasses": [
#       "Line_34_jupyter",
#       "Line_15_jupyter",
#       "Line_23_jupyter",
#       "Line_29_jupyter",
#       "Line_35_jupyter"
#      ]
#     },
#     "ExecuteTime": {
#      "end_time": "2026-02-21T17:16:01.143161600Z",
#      "start_time": "2026-02-21T17:15:59.740580100Z"
#     }
#    },
#    "cell_type": "code",
#    "source": [
#     "er.waitingLine.sizeTimeline.clip(start=er.startDate+7.days, end=er.startDate+10.days).display(\"waiting line (2d)\")\n",
#     "//display(\"Waiting Line\")"
#    ],
#    "id": "7b6c4a4015ecb0fe",
#    "outputs": [
#     {
#      "data": {
#       "image/jpeg": "..."
#      },
#      "execution_count": 30,
#      "metadata": {},
#      "output_type": "execute_result"
#     }
#    ],
#    "execution_count": 30
#   },
#   {
#    "metadata": {
#     "executionRelatedData": {
#      "compiledClasses": [
#       "Line_18_jupyter",
#       "Line_17_jupyter",
#       "Line_24_jupyter",
#       "Line_16_jupyter",
#       "Line_30_jupyter"
#      ]
#     },
#     "ExecuteTime": {
#      "end_time": "2026-02-21T17:13:34.327826500Z",
#      "start_time": "2026-02-21T17:13:32.964721900Z"
#     }
#    },
#    "cell_type": "code",
#    "source": [
#     "\n",
#     "//er.incomingMonitor.display(\"Incoming Patients\")\n",
#     "er.waitingLine.lengthOfStayStatistics.display()\n",
#     "\n"
#    ],
#    "id": "9bfc9b24bceba216",
#    "outputs": [
#     {
#      "data": {
#       "image/jpeg": "..."
#      },
#      "execution_count": 25,
#      "metadata": {},
#      "output_type": "execute_result"
#     }
#    ],
#    "execution_count": 25
#   },
#   {
#    "metadata": {
#     "executionRelatedData": {
#      "compiledClasses": [
#       "Line_25_jupyter",
#       "Line_19_jupyter",
#       "Line_31_jupyter"
#      ]
#     },
#     "ExecuteTime": {
#      "end_time": "2026-02-21T17:13:38.797918300Z",
#      "start_time": "2026-02-21T17:13:37.407665Z"
#     }
#    },
#    "cell_type": "code",
#    "source": "er.waitingLine.sizeTimeline.display()",
#    "id": "96413d6bdd007ad9",
#    "outputs": [
#     {
#      "data": {
#       "image/jpeg": "..."
#      },
#      "execution_count": 26,
#      "metadata": {},
#      "output_type": "execute_result"
#     }
#    ],
#    "execution_count": 26
#   },
#   {
#    "metadata": {},
#    "cell_type": "code",
#    "outputs": [],
#    "execution_count": null,
#    "source": [
#     "er.treatedMonitor.display(\"Treated Patients\")\n",
#     "er.deceasedMonitor.display(\"Deceased Patients\")"
#    ],
#    "id": "7f59f29dab9b8da4"
#   },
#   {
#    "metadata": {
#     "ExecuteTime": {
#      "end_time": "2026-02-20T18:05:13.965760100Z",
#      "start_time": "2026-02-20T18:05:13.640722700Z"
#     }
#    },
#    "cell_type": "code",
#    "source": "rae.toDataFrame().writeCSV(File(\"er.csv\"))",
#    "id": "342ed106efb63736",
#    "outputs": [],
#    "execution_count": 9
#   },
#   {
#    "metadata": {
#     "ExecuteTime": {
#      "end_time": "2026-02-20T18:05:07.059945800Z",
#      "start_time": "2026-02-20T18:05:07.046947Z"
#     }
#    },
#    "cell_type": "code",
#    "source": "",
#    "id": "4a1282af8976c4eb",
#    "outputs": [],
#    "execution_count": 8
#   },
#   {
#    "metadata": {},
#    "cell_type": "code",
#    "source": [
#     "val rae= er.collect<InteractionEvent> (  )\n",
#     "er.run(365.days)\n"
#    ],
#    "id": "e1da29221e11b198",
#    "execution_count": null,
#    "outputs": []
#   },
#   {
#    "metadata": {},
#    "cell_type": "code",
#    "outputs": [
#     {
#      "data": {
#       "text/html": [
#        "   <div id=\"iHo8LI\"></div>\n",
#        "   <script type=\"text/javascript\" data-lets-plot-script=\"library\">\n",
#        "       if(!window.letsPlotCallQueue) {\n",
#        "           window.letsPlotCallQueue = [];\n",
#        "       }; \n",
#        "       window.letsPlotCall = function(f) {\n",
#        "           window.letsPlotCallQueue.push(f);\n",
#        "       };\n",
#        "       (function() {\n",
#        "           var script = document.createElement(\"script\");\n",
#        "           script.type = \"text/javascript\";\n",
#        "           script.src = \"https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.3.0/js-package/distr/lets-plot.min.js\";\n",
#        "           script.onload = function() {\n",
#        "               window.letsPlotCall = function(f) {f();};\n",
#        "               window.letsPlotCallQueue.forEach(function(f) {f();});\n",
#        "               window.letsPlotCallQueue = [];\n",
#        "               \n",
#        "               \n",
#        "           };\n",
#        "           script.onerror = function(event) {\n",
#        "               window.letsPlotCall = function(f) {};\n",
#        "               window.letsPlotCallQueue = [];\n",
#        "               var div = document.createElement(\"div\");\n",
#        "               div.style.color = 'darkred';\n",
#        "               div.textContent = 'Error loading Lets-Plot JS';\n",
#        "               document.getElementById(\"iHo8LI\").appendChild(div);\n",
#        "           };\n",
#        "           var e = document.getElementById(\"iHo8LI\");\n",
#        "           e.appendChild(script);\n",
#        "       })();\n",
#        "   </script>"
#       ]
#      },
#      "metadata": {},
#      "output_type": "display_data",
#      "jetTransient": {
#       "display_id": null
#      }
#     },
#     {
#      "name": "stderr",
#      "output_type": "stream",
#      "text": [
#       "The problem is found in one of the loaded libraries: check library init codes\n",
#       "java.lang.NoSuchMethodError: 'void org.jetbrains.letsPlot.LetsPlot.setOutputsDescription(java.lang.String)'\n",
#       "org.jetbrains.kotlinx.jupyter.exceptions.ReplLibraryException: The problem is found in one of the loaded libraries: check library init codes\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.exceptions.CompositeReplExceptionKt.throwAsLibraryException(CompositeReplException.kt:48)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.exceptions.ReplLibraryExceptionKt.rethrowAsLibraryException(ReplLibraryException.kt:42)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$ExecutionContext.doAddLibraries(CellExecutorImpl.kt:182)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$ExecutionContext.addLibraries(CellExecutorImpl.kt:258)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.libraries.LibrariesScanner.addLibrariesFromClassLoader(LibrariesScanner.kt:79)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.libraries.LibrariesScanner.addLibrariesFromClassLoader$default(LibrariesScanner.kt:68)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute_W38Nk0s$lambda$0$4(CellExecutorImpl.kt:126)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.config.LoggingKt.catchAll(Logging.kt:33)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.config.LoggingKt.catchAll$default(Logging.kt:27)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute-W38Nk0s(CellExecutorImpl.kt:125)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.repl.execution.CellExecutor.execute-W38Nk0s$default(CellExecutor.kt:14)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$ExecutionContext.execute(CellExecutorImpl.kt:307)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.api.libraries.CodeExecutionCallback.invoke(CodeExecutionCallback.kt:9)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.api.libraries.CodeExecutionCallback.invoke(CodeExecutionCallback.kt:6)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$ExecutionContext.execute(CellExecutorImpl.kt:340)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$ExecutionContext.runChild(CellExecutorImpl.kt:171)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$ExecutionContext.runChild(CellExecutorImpl.kt:167)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$ExecutionContext.doAddLibraries$lambda$0(CellExecutorImpl.kt:179)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.exceptions.ReplLibraryExceptionKt.rethrowAsLibraryException(ReplLibraryException.kt:40)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$ExecutionContext.doAddLibraries(CellExecutorImpl.kt:178)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$ExecutionContext.addLibraries(CellExecutorImpl.kt:258)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.api.KotlinKernelHost.addLibrary(KotlinKernelHost.kt:50)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$ExecutionContext.addLibrary(CellExecutorImpl.kt:159)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute-W38Nk0s(CellExecutorImpl.kt:79)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.repl.execution.CellExecutor.execute-W38Nk0s$default(CellExecutor.kt:14)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evaluateUserCode-wNURfNM(ReplForJupyterImpl.kt:591)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalExImpl(ReplForJupyterImpl.kt:472)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalEx$lambda$0(ReplForJupyterImpl.kt:466)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withEvalContext(ReplForJupyterImpl.kt:448)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalEx(ReplForJupyterImpl.kt:465)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.processExecuteRequest$lambda$0$0$0(IdeCompatibleMessageRequestProcessor.kt:161)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:124)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedIn(IdeCompatibleMessageRequestProcessor.kt:351)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.evalWithIO$lambda$0$0(IdeCompatibleMessageRequestProcessor.kt:364)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:124)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedErr(IdeCompatibleMessageRequestProcessor.kt:341)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.evalWithIO$lambda$0(IdeCompatibleMessageRequestProcessor.kt:363)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:124)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedOut(IdeCompatibleMessageRequestProcessor.kt:334)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.evalWithIO(IdeCompatibleMessageRequestProcessor.kt:362)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.processExecuteRequest$lambda$0$0(IdeCompatibleMessageRequestProcessor.kt:160)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$Task.execute(JupyterExecutorImpl.kt:41)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl.executorThread$lambda$0(JupyterExecutorImpl.kt:81)\r\n",
#       "\tat kotlin.concurrent.ThreadsKt$thread$thread$1.run(Thread.kt:30)\r\n",
#       "Caused by: java.lang.NoSuchMethodError: 'void org.jetbrains.letsPlot.LetsPlot.setOutputsDescription(java.lang.String)'\r\n",
#       "\tat org.jetbrains.letsPlot.toolkit.jupyter.Integration$onLoaded$1.invoke(Integration.kt:112)\r\n",
#       "\tat org.jetbrains.letsPlot.toolkit.jupyter.Integration$onLoaded$1.invoke(Integration.kt:100)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$ExecutionContext.execute(CellExecutorImpl.kt:340)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$ExecutionContext.runChild(CellExecutorImpl.kt:171)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$ExecutionContext.doAddLibraries$lambda$1(CellExecutorImpl.kt:183)\r\n",
#       "\tat org.jetbrains.kotlinx.jupyter.exceptions.ReplLibraryExceptionKt.rethrowAsLibraryException(ReplLibraryException.kt:40)\r\n",
#       "\t... 45 more\r\n",
#       "\n",
#       "\r\n"
#      ]
#     }
#    ],
#    "execution_count": 10,
#    "source": [
#     "%use lets-plot\n",
#     "%use dataframe"
#    ],
#    "id": "6eff8a93d92284ed"
#   },
#   {
#    "metadata": {},
#    "cell_type": "code",
#    "outputs": [],
#    "execution_count": null,
#    "source": "",
#    "id": "7073797e1612fda0"
#   }
#  ],
#  "metadata": {
#   "kernelspec": {
#    "display_name": "Kotlin",
#    "language": "kotlin",
#    "name": "kotlin"
#   },
#   "language_info": {
#    "name": "kotlin",
#    "version": "2.2.20",
#    "mimetype": "text/x-kotlin",
#    "file_extension": ".kt",
#    "pygments_lexer": "kotlin",
#    "codemirror_mode": "text/x-kotlin",
#    "nbconvert_exporter": ""
#   },
#   "ktnbPluginMetadata": {
#    "projectDependencies": [
#     "kalasim.modules.notebook.test"
#    ],
#    "projectLibraries": false
#   }
#  },
#  "nbformat": 4,
#  "nbformat_minor": 5
# }
