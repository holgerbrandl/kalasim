// %%
%useLatestDescriptors
%use kandy

plot {
    bars {
        x(listOf("first", "second", "third"))
        y(listOf(7, 3, 5))
    }
}
// Out:
// The problem is found in one of the loaded libraries: check library renderers
// java.lang.NoSuchMethodError: 'void org.jetbrains.letsPlot.Geom$bar.<init>(java.lang.Number, java.lang.Number, java.lang.Number, java.lang.Object, java.lang.Object, java.lang.Number, java.lang.Number, java.lang.String, java.lang.String, kotlin.jvm.functions.Function1, int, kotlin.jvm.internal.DefaultConstructorMarker)'
// org.jetbrains.kotlinx.jupyter.exceptions.ReplLibraryException: The problem is found in one of the loaded libraries: check library renderers
// 	at org.jetbrains.kotlinx.jupyter.exceptions.ReplLibraryExceptionKt.rethrowAsLibraryException(ReplLibraryException.kt:38)
// 	at org.jetbrains.kotlinx.jupyter.codegen.RenderersProcessorImpl.renderResult(RenderersProcessorImpl.kt:35)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl$renderResult$1$1.invoke(ReplForJupyterImpl.kt:484)
// 	at org.jetbrains.kotlinx.jupyter.config.LoggingKt.catchAll(Logging.kt:33)
// ...

// %%
:classpath
// Out:
// Current classpath (490 paths):
// C:\Users\brandl\AppData\Local\JetBrains\IntelliJIdea2024.2\kotlinNotebook\kalasim.bd5f1fcd\kernels\0.12.0-285\kotlin-jupyter-script-classpath-shadowed-zip_extracted\annotations-13.0.jar
// C:\Users\brandl\AppData\Local\JetBrains\IntelliJIdea2024.2\kotlinNotebook\kalasim.bd5f1fcd\kernels\0.12.0-285\kotlin-jupyter-script-classpath-shadowed-zip_extracted\api-0.12.0-285.jar
// C:\Users\brandl\AppData\Local\JetBrains\IntelliJIdea2024.2\kotlinNotebook\kalasim.bd5f1fcd\kernels\0.12.0-285\kotlin-jupyter-script-classpath-shadowed-zip_extracted\kotlin-reflect-1.9.23.jar
// C:\Users\brandl\AppData\Local\JetBrains\IntelliJIdea2024.2\kotlinNotebook\kalasim.bd5f1fcd\kernels\0.12.0-285\kotlin-jupyter-script-classpath-shadowed-zip_extracted\kotlin-script-runtime-1.9.23.jar
// C:\Users\brandl\AppData\Local\JetBrains\IntelliJIdea2024.2\kotlinNotebook\kalasim.bd5f1fcd\kernels\0.12.0-285\kotlin-jupyter-script-classpath-shadowed-zip_extracted\kotlin-stdlib-1.9.23.jar
// ...
